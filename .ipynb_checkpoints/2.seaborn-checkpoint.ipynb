# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
plt.rc('font', family="Malgun Gothic")

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
tips.groupby('day').count()['total_bill']
# Out:
# day
# Thur    62
# Fri     19
# Sat     87
# Sun     76
# Name: total_bill, dtype: int64

# %%
group = tips.groupby('day').count()['total_bill']
x = list(group.index)
y = list(group)
x, y
# Out:
# (['Thur', 'Fri', 'Sat', 'Sun'], [62, 19, 87, 76])

# %%
group = tips.groupby('day').count()['total_bill']
x = list(group.index)
y = list(group)
print(x, y)
plt.bar(x,y)
# Out:
# ['Thur', 'Fri', 'Sat', 'Sun'] [62, 19, 87, 76]
# <BarContainer object of 4 artists>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
group = tips.groupby('day').sum()['total_bill']
print( group )
x = list(group.index )
y = list(group )
print( x, y )
sns.barplot( x=x, y=y )
# Out:
# day
# Thur    1096.33
# Fri      325.88
# Sat     1778.40
# Sun     1627.16
# Name: total_bill, dtype: float64
# ['Thur', 'Fri', 'Sat', 'Sun'] [1096.33, 325.88, 1778.4, 1627.16]
# <Axes: >

# %%
fig, axes = plt.subplots(1,2,figsize=(10,3))
sns.barplot(x='day', y='total_bill', data = tips, ax = axes[0])
data = tips.groupby('day').describe()['total_bill']['mean'];
x_data = data.index
x_data
y_data = list(data)

sns.barplot(x=x_data, y=y_data, ax=axes[1])
# Out:
# <Axes: xlabel='day'>

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.groupby('day').describe()['total_bill']['mean']
# Out:
# day
# Thur    17.682742
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Name: mean, dtype: float64

# %% [markdown]
# 1 replot

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x="total_bill", y = "tip", hue='day', data = tips)

# %%
sns.relplot(x="total_bill", y = "tip", hue='day', data = tips, col="day")

# %%
g = sns.scatterplot(x="total_bill", y = "tip", hue='day', data = tips)
g.set_title("scatterplot", fontsize=20, color="blue")
# Out:
# Text(0.5, 1.0, 'scatterplot')

# %%
plt.subplots(figsize=(3,3))
sns.lineplot(x="total_bill", y="tip", hue="day", data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
fig, ax = plt.subplots(figsize=(10,4))
g = sns.distplot(x=titanic['age'], color="darkblue", bins = 10)
ax.set_title("DisPlot", fontsize=15)
# Out:
# Text(0.5, 1.0, 'DisPlot')

# %%
fig, ax = plt.subplots(figsize=(10,4))
g = sns.histplot(x=titanic['age'], color="skyblue", bins = 10)
ax.set_title("DisPlot", fontsize=15)
# Out:
# Text(0.5, 1.0, 'DisPlot')

# %%
plt.subplots(figsize=(10,3))
sns.boxplot(x="day", y="total_bill", hue="smoker", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#상관관계를 표현해줌
#0.7이상이면 어느정도 관계가 있으며 0.3 이하이면 관계가 없다고 표현
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
tips[['total_bill', 'tip','size']].corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr(), annot = True)
# Out:
# <Axes: >

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df_replace = pd.DataFrame(min_max_df, columns['장소부족', '비용부족'])
#       2 df_replace['분류'] = df_sort['분류'].values
#       3 df_replace.head()
#
# NameError: name 'min_max_df' is not defined
